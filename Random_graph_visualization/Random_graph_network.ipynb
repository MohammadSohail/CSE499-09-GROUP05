# %%
import networkx as nx
import matplotlib.pyplot as nzm
# %matplotlib inline

# %%
import os
os.listdir()
# Out:
# ['.android',
#  '.bash_history',
#  '.eclipse',
#  '.git',
#  '.gitconfig',
#  '.IdeaIC2018.3',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.keras',
#  '.matplotlib',
#  '.nbi',
#  '.oracle_jre_usage',
#  '.Origin',
#  '.p2',
#  '.packettracer',
#  '.QtWebEngineProcess',
#  '.vscode',
#  '3D Objects',
#  'Anaconda3',
#  'AppData',
#  'Application Data',
#  'as network.ipynb',
#  'Cisco Packet Tracer 7.1.1',
#  'Contacts',
#  'Cookies',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'IdeaProjects',
#  'IntelGraphicsProfiles',
#  'Links',
#  'Local Settings',
#  'MicrosoftEdgeBackups',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{1753cd48-973d-11e8-818e-3497f6c31ee2}.TM.blf',
#  'NTUSER.DAT{1753cd48-973d-11e8-818e-3497f6c31ee2}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{1753cd48-973d-11e8-818e-3497f6c31ee2}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'p2p-Gnutella08.txt',
#  'Pictures',
#  'PrintHood',
#  'random_graph_data.txt',
#  'Random_graph_network.ipynb',
#  'README.md',
#  'Recent',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'Start Menu',
#  'Templates',
#  'Tracing',
#  'Videos',
#  'workspace']

# %%
#read in file
p = nx.read_edgelist('random_graph_data.txt',create_using=nx.Graph(),nodetype=int)

# %%
print(nx.info(p))
# Out:
# Name:
# Type: Graph
# Number of nodes: 6000
# Number of edges: 456103
# Average degree: 152.0343

# %%
#create a layout of fb
pos = nx.spring_layout(p)
nzm.figure(figsize=(15,12))
nzm.axis('on')
nx.draw_networkx(p,pos=pos,with_labels=False,node_size=50)
# Out:
# C:\Users\Nazmul\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):
