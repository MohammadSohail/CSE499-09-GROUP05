# %%
import collections
import networkx as nx
import matplotlib.pyplot as nzm
# %matplotlib inline

# %%
import os
os.listdir()
# Out:
# ['.anaconda',
#  '.android',
#  '.atom',
#  '.conda',
#  '.condarc',
#  '.IdeaIC2019.1',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.PyCharmCE2019.1',
#  '2015_FIFA_1M.txt',
#  '3D Objects',
#  '9_11_HIJACKERS_ASSOCIATES.txt',
#  'Amazon0302.txt',
#  'Anaconda3',
#  'AppData',
#  'Application Data',
#  'artist_edges_text.txt',
#  'as network.ipynb',
#  'BALIBOMBING2002_2000.txt',
#  'com-amazon.all.dedup.cmty.txt',
#  'com-amazon.top5000.cmty.txt',
#  'com-amazon.ungraph.txt',
#  'CommViolPredUnnormalizedData.txt',
#  'company_edges_txt.txt',
#  'Contacts',
#  'Cookies',
#  'CSE499-09-GROUP05-master',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'email-Eu-core-temporal-Dept1.txt',
#  'email-Eu-core-temporal-Dept2.txt',
#  'email-Eu-core-temporal-Dept3.txt',
#  'email-Eu-core-temporal-Dept4.txt',
#  'Favorites',
#  'government_edges_txt.txt',
#  'IdeaProjects',
#  'IntelGraphicsProfiles',
#  'Links',
#  'Local Settings',
# ...

# %%
#read in file
p = nx.read_edgelist('p2p-Gnutella04.txt',create_using=nx.Graph(),nodetype=int)

# %%
print(nx.info(p))
# Out:
# Name:
# Type: Graph
# Number of nodes: 10876
# Number of edges: 39994
# Average degree:   7.3545

# %%
nx.pagerank(p, alpha=0.9)
# Out:
# {0: 0.0001858144372324605,
#  1: 0.00015993739948408613,
#  2: 0.00010833240986478518,
#  3: 0.00019858910319450784,
#  4: 0.00018039241821252782,
#  5: 8.54218597851291e-05,
#  6: 9.089256112518414e-05,
#  7: 6.026812882612393e-05,
#  8: 0.00013553462713863934,
#  9: 0.00018865925232209894,
#  10: 0.00016175382776504463,
#  11: 0.0001343903375799692,
#  12: 0.00016271556989969128,
#  13: 0.0001273920256490358,
#  14: 0.00014789967603988588,
#  15: 5.112754776540675e-05,
#  16: 0.00010734350301703336,
#  17: 0.00017586904296700763,
#  18: 0.00012647658107046238,
#  19: 0.00016307487538922915,
#  20: 0.0001727634072553832,
#  21: 0.00014473488287965658,
#  22: 7.576489356644978e-05,
#  23: 0.0001549535164136713,
#  24: 2.0347994863365914e-05,
#  25: 0.00020625941782666056,
#  26: 0.000199514800434874,
#  27: 6.211094761282374e-05,
#  28: 2.0347994863365914e-05,
#  29: 4.5595283685593245e-05,
#  30: 0.00018468649177736778,
#  31: 0.0001254164120965734,
#  32: 2.015321192235554e-05,
# ...
