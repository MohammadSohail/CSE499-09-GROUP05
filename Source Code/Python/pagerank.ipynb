# %%
import collections
import networkx as nx
import matplotlib.pyplot as nzm
# %matplotlib inline

# %%
import os
os.listdir()
# Out:
# ['.anaconda',
#  '.android',
#  '.atom',
#  '.conda',
#  '.condarc',
#  '.IdeaIC2019.1',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.PyCharmCE2019.1',
#  '2015_FIFA_1M.txt',
#  '3D Objects',
#  '9_11_HIJACKERS_ASSOCIATES.txt',
#  'Amazon0302.txt',
#  'Anaconda3',
#  'AppData',
#  'Application Data',
#  'artist_edges_text.txt',
#  'as network.ipynb',
#  'BALIBOMBING2002_2000.txt',
#  'com-amazon.all.dedup.cmty.txt',
#  'com-amazon.top5000.cmty.txt',
#  'com-amazon.ungraph.txt',
#  'CommViolPredUnnormalizedData.txt',
#  'company_edges_txt.txt',
#  'Contacts',
#  'Cookies',
#  'CSE499-09-GROUP05-master',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'email-Eu-core-temporal-Dept1.txt',
#  'email-Eu-core-temporal-Dept2.txt',
#  'email-Eu-core-temporal-Dept3.txt',
#  'email-Eu-core-temporal-Dept4.txt',
#  'Favorites',
#  'government_edges_txt.txt',
#  'IdeaProjects',
#  'IntelGraphicsProfiles',
#  'Links',
#  'Local Settings',
# ...

# %%
#read in file
p = nx.read_edgelist('p2p-Gnutella06.txt',create_using=nx.Graph(),nodetype=int)

# %%
print(nx.info(p))
# Out:
# Name:
# Type: Graph
# Number of nodes: 8717
# Number of edges: 31525
# Average degree:   7.2330

# %%
nx.pagerank(p, alpha=0.9)
# Out:
# {0: 0.00017446223021656834,
#  1: 6.552591002453048e-05,
#  2: 8.803923849465175e-05,
#  3: 0.00017641743435338434,
#  4: 8.792198951352263e-05,
#  5: 0.00014529968164724399,
#  6: 0.0002920886055275046,
#  7: 0.0001847483389600638,
#  8: 0.00024685895419299586,
#  9: 0.00020024836548685046,
#  10: 0.00026201510949811624,
#  21: 0.0002146898603843509,
#  327: 0.0003559529416953022,
#  619: 0.0001596950471648552,
#  1828: 0.00022517495887923043,
#  2173: 0.00018106816485818935,
#  2201: 0.00015955324249108244,
#  2743: 0.00011133868276701469,
#  2744: 0.00015785857896239518,
#  2745: 0.00024214592123195225,
#  2746: 0.00020573481998991964,
#  372: 0.00014349001647080413,
#  437: 0.0002785335927192032,
#  816: 0.0006576070747020929,
#  1826: 0.00012851884964803505,
#  1913: 0.00019733032622836082,
#  2303: 0.00012178348710200151,
#  2734: 6.438479976542752e-05,
#  2735: 5.41582518450261e-05,
#  2736: 0.00011907354291091499,
#  2737: 3.912252044120034e-05,
# ...

# %%
import collections
import networkx as nx
import matplotlib.pyplot as nzm
# %matplotlib inline
import os
os.listdir()
#read in file
p = nx.read_edgelist('p2p-Gnutella05.txt',create_using=nx.Graph(),nodetype=int)

# %%
# %%capture cap --no-stderr
with open('p2p-Gnutella05_pagerank.txt', 'a') as f:
    f.write(cap.stdout)
    print(nx.pagerank(p, alpha=0.9))
f.close()

# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy.linalg

n = 1000  # 1000 nodes
m = 5000  # 5000 edges
G = nx.gnm_random_graph(n, m)

L = nx.normalized_laplacian_matrix(G)
e = numpy.linalg.eigvals(L.A)
print("Largest eigenvalue:", max(e))
print("Smallest eigenvalue:", min(e))
plt.hist(e, bins=100)  # histogram with 100 bins
plt.xlim(0, 2)  # eigenvalues between 0 and 2
plt.show()
