# %%
import networkx as nx
import matplotlib.pyplot as nzm
# %matplotlib inline

# %%
import os
os.listdir()
# Out:
# ['.android',
#  '.bash_history',
#  '.eclipse',
#  '.git',
#  '.gitconfig',
#  '.IdeaIC2018.3',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.keras',
#  '.matplotlib',
#  '.nbi',
#  '.oracle_jre_usage',
#  '.Origin',
#  '.p2',
#  '.packettracer',
#  '.QtWebEngineProcess',
#  '.vscode',
#  '3D Objects',
#  'Anaconda3',
#  'AppData',
#  'Application Data',
#  'as network.ipynb',
#  'Cisco Packet Tracer 7.1.1',
#  'Contacts',
#  'Cookies',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'IdeaProjects',
#  'IntelGraphicsProfiles',
#  'Links',
#  'Local Settings',
#  'MicrosoftEdgeBackups',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{1753cd48-973d-11e8-818e-3497f6c31ee2}.TM.blf',
#  'NTUSER.DAT{1753cd48-973d-11e8-818e-3497f6c31ee2}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{1753cd48-973d-11e8-818e-3497f6c31ee2}.TMContainer00000000000000000002.regtrans-ms',
# ...

# %%
#read in file
p = nx.read_edgelist('p2p-Gnutella08.txt',create_using=nx.Graph(),nodetype=int)

# %%
print(nx.info(p))
# Out:
# Name:
# Type: Graph
# Number of nodes: 6299
# Number of edges: 20776
# Average degree:   6.5966

# %%
#create a layout of fb
pos = nx.spring_layout(p)
nzm.figure(figsize=(15,12))
nzm.axis('on')
nx.draw_networkx(p,pos=pos,with_labels=False,node_size=50)
# Out:
# C:\Users\Nazmul\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
nx.pagerank(p, alpha=0.9)
# Out:
# {0: 0.00020266041550797827,
#  1: 3.3878783157003606e-05,
#  2: 0.00012095351312624743,
#  3: 0.0014949795109241442,
#  4: 0.0011897472131462883,
#  5: 0.0013491070375446367,
#  6: 3.3878783157003606e-05,
#  7: 0.000979052375075378,
#  8: 0.0014496173243504539,
#  9: 0.0009621955449166407,
#  10: 0.00012823886532862798,
#  703: 0.00033699933081511954,
#  826: 9.657312011985497e-05,
#  1097: 0.00016249870778653643,
#  1287: 0.0003798338000813315,
#  1591: 0.00026393404132338017,
#  1895: 5.481092686541543e-05,
#  1896: 0.00033046824367136975,
#  1897: 3.1425869814349336e-05,
#  1898: 7.508790746249285e-05,
#  1899: 5.2673243473423275e-05,
#  144: 0.0012834357762248206,
#  258: 5.289792073145811e-05,
#  491: 0.0002518335674736108,
#  1021: 0.00025351522196034106,
#  1418: 5.112655656302704e-05,
#  1669: 0.0002877033757815666,
#  1900: 0.00016141616969308128,
#  1901: 0.00014082966042501185,
#  1902: 3.1458125208955586e-05,
#  1903: 0.00024841223944620656,
# ...

# %%
nx.betweenness_centrality(p, k=None, normalized=True, weight=None, endpoints=False, seed=None)
# Out:
# {0: 0.0007083523594039867,
#  1: 0.0,
#  2: 2.95977084970367e-05,
#  3: 0.009878886205085882,
#  4: 0.005978157508074944,
#  5: 0.005617197652005053,
#  6: 0.0,
#  7: 0.002890150551291635,
#  8: 0.011231486674380948,
#  9: 0.0036687639684755847,
#  10: 2.2576626397338017e-05,
#  703: 0.001780884818724858,
#  826: 0.00019979910108958277,
#  1097: 0.0006502747893926701,
#  1287: 0.0028277512127637076,
#  1591: 0.0012287702992398839,
#  1895: 4.29437594264907e-05,
#  1896: 0.0015750635010840478,
#  1897: 0.0,
#  1898: 9.602929534170178e-05,
#  1899: 3.164656269523115e-05,
#  144: 0.00521008029500968,
#  258: 2.4438520832455298e-05,
#  491: 0.0014275482997509164,
#  1021: 0.001326824773985996,
#  1418: 9.595512771027088e-06,
#  1669: 0.0012300807947778333,
#  1900: 0.00036269395678348315,
#  1901: 0.00045405689397908774,
#  1902: 0.0,
#  1903: 0.0012855456782337124,
#  121: 0.001728945602943153,
#  127: 0.009021147473387293,
#  128: 0.0014864968893545621,
#  179: 0.006415244297023545,
# ...
